# %%
"""
# !pip install pyvis
# !pip install langchain
# !pip install langchain_community
# !pip install google.generativeai
# !pip install neo4j
"""
# Out:
# '\n!pip install pyvis\n!pip install langchain\n!pip install langchain_community\n!pip install google.generativeai\n!pip install neo4j\n'

# %%
import pandas as pd
from pyvis.network import Network
from langchain_community.graphs import Neo4jGraph
import google.generativeai as genai
import time
import json
import re

# %%
#graph database test
NEO4J_URL = "bolt://localhost:7687"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "hqiineo4jay"
NEO4J_DATABASE = "neo4j"

graph = Neo4jGraph(
    url=NEO4J_URL,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    database=NEO4J_DATABASE
)

print("okay")
# #graph database chính 
# NEO4J_URL = "bolt://localhost:7687"
# NEO4J_USERNAME = "neo4j"
# NEO4J_PASSWORD = "hqiineo4j"
# NEO4J_DATABASE = "neo4j"

# graph = Neo4jGraph(
#     url=NEO4J_URL,
#     username=NEO4J_USERNAME,
#     password=NEO4J_PASSWORD,
#     database=NEO4J_DATABASE
# )

# print("connected")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6856\2421235633.py:7: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-neo4j package and should be used instead. To use it run `pip install -U :class:`~langchain-neo4j` and import as `from :class:`~langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph(
# okay

# %%
df = pd.read_csv("cloth.csv")
df.head(5)
# Out:
#                              name              material        color   brand  \
# 0            Áo sơ mi nam công sở                Cotton        Trắng    Zara
# 1                Quần jean skinny   Denim pha Polyester    Xanh navy     H&M
# 2                 Áo khoác dạ dài     Len pha Polyester          Đen  Uniqlo
# 3                Váy maxi vintage              Voan nhẹ  Hồng pastel   Mango
# 4  Bộ thể thao Adidas Performance  Thun co giãn 4 chiều     Xám, Đen  Adidas
#
#         style                event_type  \
# 0  Sang trọng                   Công sở
# 1   Trẻ trung             Dạo phố, Tiệc
# 2  Minimalist      Công sở, Trang trọng
# 3     Vintage  Dạo phố, Tiệc ngoài trời
# 4  Athleisure                  Thể thao
#
#                                          description  price
# 0  Chiếc áo sơ mi nam cao cấp của Zara, được làm ...    100
# 1  Quần jean skinny fit của H&M mang đến phong cá...   2500
# 2  Mẫu áo khoác dáng dài của Uniqlo là sự kết hợp...    124
# 3  Váy maxi phong cách vintage từ thương hiệu Man...    344
# 4  Bộ đồ thể thao Adidas Performance, thiết kế dà...    853

# %%
def join_string(row):
    fields = [
        row["name"], row["material"], row["color"],
        row["brand"], row["style"], row["event_type"],
        row["description"], row["price"]
    ]
    return "|".join([str(f) for f in fields if pd.notna(f)])

# Áp dụng hàm cho DataFrame
df["info"] = df.apply(join_string, axis=1)

sample = df.head().iloc[0]["info"]
sample
# Out:
# 'Áo sơ mi nam công sở|Cotton|Trắng|Zara|Sang trọng|Công sở|Chiếc áo sơ mi nam cao cấp của Zara, được làm từ 100% cotton, mang lại cảm giác mềm mại và thoáng mát. Sản phẩm có màu trắng, kiểu dáng regular fit, phù hợp với môi trường công sở hoặc các sự kiện trang trọng.|100'

# %%
genai.configure(api_key="AIzaSyAmLesw2keGhIrZPMEyYJUs1PUqIidIWFU")
model = genai.GenerativeModel("gemini-2.0-flash")

def extract_entities_and_relationships(text):
    prompt = (
        "Trích xuất các thực thể (nodes) và mối quan hệ (edges) từ văn bản tôi cung cấp. "
        "Các trường dữ liệu được ngăn cách bằng dấu '|', gồm: name, material, color, brand, style, event_type, description, price. "
        "Với thông nhất về cách đặt tên mối quan hệ như sau, trong trường hợp không có thì hãy bổ sung, còn tương đồng thì hãy đặt tên theo mẫu cho tôi: làm từ chất liệu, có màu sắc, thuộc thương hiệu, mang phong cách, phù hợp với, có giá, có mô tả, dùng cho mùa"
        "Tên thực thể và mối quan hệ PHẢI được viết bằng tiếng Việt.\n\n"
        "Theo định dạng sau:\n"
        "Entities:\n"
        "- {Entity}: {Type}\n\n"
        "Relationships:\n"
        "- ({Entity1}, {RelationshipType}, {Entity2}\n\n)"
        f"Văn bản cần trích xuất:\n\"{text}\"\n\n"
        "Output:\nEntities:\n- {Entity}: {Type}\n...\n\n"
        "Relationships:\n- {Entity1}, {RelationshipType}, {Entity2}\n"
    )

    response = model.generate_content(prompt)

    return response.text  # Lấy phản hồi cuối cùng của AI

# %%
result = extract_entities_and_relationships(sample)
print(result)
# Out:
# Entities:
# - Áo sơ mi nam công sở: Sản phẩm
# - Cotton: Chất liệu
# - Trắng: Màu sắc
# - Zara: Thương hiệu
# - Sang trọng: Phong cách
# - Công sở: Loại sự kiện
#
# Relationships:
# - (Áo sơ mi nam công sở, làm từ chất liệu, Cotton)
# - (Áo sơ mi nam công sở, có màu sắc, Trắng)
# - (Áo sơ mi nam công sở, thuộc thương hiệu, Zara)
# - (Áo sơ mi nam công sở, mang phong cách, Sang trọng)
# - (Áo sơ mi nam công sở, phù hợp với, Công sở)
# - (Áo sơ mi nam công sở, có giá, 100)
# - (Áo sơ mi nam công sở, có mô tả, Chiếc áo sơ mi nam cao cấp của Zara, được làm từ 100% cotton, mang lại cảm giác mềm mại và thoáng mát. Sản phẩm có màu trắng, kiểu dáng regular fit, phù hợp với môi trường công sở hoặc các sự kiện trang trọng.)

# %%
def process_llm_out(result):
  response = result

  #Extract entities
  entity_pattern = r"- (.+): (.+)"
  entities = re.findall(entity_pattern, response)
  entity_dict = {entity.strip(): entity_type.strip() for entity, entity_type in entities}

  entity_list = list(entity_dict.keys())
  entity_type_list = list(entity_dict.values())

  #Extract relationships
  relationship_pattern = r"- \(([^,]+), ([^,]+), ([^)]+)\)"
  relationships = re.findall(relationship_pattern, response)
  relationship_list = [(subject.strip(), relation.strip().replace(" ","_").upper(), object_.strip()) for subject, relation, object_ in relationships]

  print("Entities:")
  for entity, entity_type in entity_dict.items():
    print(f"{entity}: {entity_type}")

  print("\nRelationships:")
  for subject, relation, object_ in relationship_list:
    print(f"({subject}, {relation}, {object_})")

  return entity_dict, relationship_list

# %%
entities, relas = process_llm_out(result)
# Out:
# Entities:
# Áo sơ mi nam công sở: Sản phẩm
# Cotton: Chất liệu
# Trắng: Màu sắc
# Zara: Thương hiệu
# Sang trọng: Phong cách
# Công sở: Loại sự kiện
#
# Relationships:
# (Áo sơ mi nam công sở, LÀM_TỪ_CHẤT_LIỆU, Cotton)
# (Áo sơ mi nam công sở, CÓ_MÀU_SẮC, Trắng)
# (Áo sơ mi nam công sở, THUỘC_THƯƠNG_HIỆU, Zara)
# (Áo sơ mi nam công sở, MANG_PHONG_CÁCH, Sang trọng)
# (Áo sơ mi nam công sở, PHÙ_HỢP_VỚI, Công sở)
# (Áo sơ mi nam công sở, CÓ_GIÁ, 100)
# (Áo sơ mi nam công sở, CÓ_MÔ_TẢ, Chiếc áo sơ mi nam cao cấp của Zara, được làm từ 100% cotton, mang lại cảm giác mềm mại và thoáng mát. Sản phẩm có màu trắng, kiểu dáng regular fit, phù hợp với môi trường công sở hoặc các sự kiện trang trọng.)

# %%
def add_relationships_to_neo4j(graph, relationships):
  for subject, relation, obj in relationships:
    cypher_query = f"""
    MERGE (a:Entity {{name: $subject}})
    MERGE (b:Entity {{name: $object}})
    MERGE (a)-[:`{relation}`]->(b)
    """
    graph.query(cypher_query, params={"subject": subject, "object": obj})
    print("Relationships added to Neo4j database.")

# %%
def save_schema_to_json(entity_dict, relationship_list, filename="schema.json"):
    schema = {
        "nodes": [{"name": entity, "type": entity_type} for entity, entity_type in entity_dict.items()],
        "relationships": [
            {"start": subject, "type": relation, "end": object_} for subject, relation, object_ in relationship_list
        ]
    }

    with open(filename, "w", encoding="utf-8") as f:
        json.dump(schema, f, indent=2, ensure_ascii=False)
    print(f"Schema đã được lưu vào {filename}")

# %%
# Tạo từ điển tổng hợp để lưu schema của tất cả bản ghi
all_entities = {}
all_relationships = []

for i in range(len(df)):
  sample = df.iloc[i]["info"]
  result = extract_entities_and_relationships(sample)
  entity_dict, relationship_list = process_llm_out(result)
    
  # Cập nhật thực thể (nếu thực thể chưa có thì thêm vào)
  all_entities.update(entity_dict)
  # Cập nhật quan hệ
  all_relationships.extend(relationship_list)
    
  add_relationships_to_neo4j(graph, relationship_list)
  time.sleep(5)  # Chờ 10 giây để giảm tải API
# Out:
# Entities:
# Áo sơ mi nam công sở: Áo
# Cotton: Chất liệu
# Trắng: Màu sắc
# Zara: Thương hiệu
# Sang trọng: Phong cách
# Công sở: Loại sự kiện
#
# Relationships:
# (Áo sơ mi nam công sở, LÀM_TỪ_CHẤT_LIỆU, Cotton)
# (Áo sơ mi nam công sở, CÓ_MÀU_SẮC, Trắng)
# (Áo sơ mi nam công sở, THUỘC_THƯƠNG_HIỆU, Zara)
# (Áo sơ mi nam công sở, MANG_PHONG_CÁCH, Sang trọng)
# (Áo sơ mi nam công sở, PHÙ_HỢP_VỚI, Công sở)
# (Áo sơ mi nam công sở, CÓ_GIÁ, 100)
# (Áo sơ mi nam công sở, CÓ_MÔ_TẢ, Chiếc áo sơ mi nam cao cấp của Zara, được làm từ 100% cotton, mang lại cảm giác mềm mại và thoáng mát. Sản phẩm có màu trắng, kiểu dáng regular fit, phù hợp với môi trường công sở hoặc các sự kiện trang trọng.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Quần jean skinny: Sản phẩm
# Denim pha Polyester: Chất liệu
# Xanh navy: Màu sắc
# H&M: Thương hiệu
# Trẻ trung: Phong cách
# Dạo phố: Sự kiện
# Tiệc: Sự kiện
# Quần jean skinny fit của H&M mang đến phong cách trẻ trung, hiện đại. Được làm từ denim pha Polyester, giúp co giãn thoải mái và giữ form tốt.: Mô tả
# 2500: Giá
#
# Relationships:
# (Quần jean skinny, LÀM_TỪ_CHẤT_LIỆU, Denim pha Polyester)
# (Quần jean skinny, CÓ_MÀU_SẮC, Xanh navy)
# (Quần jean skinny, THUỘC_THƯƠNG_HIỆU, H&M)
# (Quần jean skinny, MANG_PHONG_CÁCH, Trẻ trung)
# (Quần jean skinny, PHÙ_HỢP_VỚI, Dạo phố)
# (Quần jean skinny, PHÙ_HỢP_VỚI, Tiệc)
# (Quần jean skinny, CÓ_MÔ_TẢ, Quần jean skinny fit của H&M mang đến phong cách trẻ trung, hiện đại. Được làm từ denim pha Polyester, giúp co giãn thoải mái và giữ form tốt.)
# (Quần jean skinny, CÓ_GIÁ, 2500)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Áo khoác dạ dài: Sản phẩm
# Len pha Polyester: Chất liệu
# Đen: Màu sắc
# Uniqlo: Thương hiệu
# Minimalist: Phong cách
# Công sở: Sự kiện
# Trang trọng: Sự kiện
# Đông: Mùa
# Mẫu áo khoác dáng dài của Uniqlo là sự kết hợp hoàn hảo giữa thời trang và tiện dụng. Chất liệu len pha polyester, giữ ấm tốt, thích hợp cho mùa đông.: Mô tả
# 124: Giá
#
# Relationships:
# (Áo khoác dạ dài, LÀM_TỪ_CHẤT_LIỆU, Len pha Polyester)
# (Áo khoác dạ dài, CÓ_MÀU_SẮC, Đen)
# (Áo khoác dạ dài, THUỘC_THƯƠNG_HIỆU, Uniqlo)
# (Áo khoác dạ dài, MANG_PHONG_CÁCH, Minimalist)
# (Áo khoác dạ dài, PHÙ_HỢP_VỚI, Công sở)
# (Áo khoác dạ dài, PHÙ_HỢP_VỚI, Trang trọng)
# (Áo khoác dạ dài, CÓ_GIÁ, 124)
# (Áo khoác dạ dài, CÓ_MÔ_TẢ, Mẫu áo khoác dáng dài của Uniqlo là sự kết hợp hoàn hảo giữa thời trang và tiện dụng. Chất liệu len pha polyester, giữ ấm tốt, thích hợp cho mùa đông.)
# (Áo khoác dạ dài, DÙNG_CHO_MÙA, Đông)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Váy maxi vintage: Sản phẩm
# Voan nhẹ: Chất liệu
# Hồng pastel: Màu sắc
# Mango: Thương hiệu
# Vintage: Phong cách
# Dạo phố: Sự kiện
# Tiệc ngoài trời: Sự kiện
# Mùa hè: Mùa
#
# Relationships:
# (Váy maxi vintage, LÀM_TỪ_CHẤT_LIỆU, Voan nhẹ)
# (Váy maxi vintage, CÓ_MÀU_SẮC, Hồng pastel)
# (Váy maxi vintage, THUỘC_THƯƠNG_HIỆU, Mango)
# (Váy maxi vintage, MANG_PHONG_CÁCH, Vintage)
# (Váy maxi vintage, PHÙ_HỢP_VỚI, Dạo phố)
# (Váy maxi vintage, PHÙ_HỢP_VỚI, Tiệc ngoài trời)
# (Váy maxi vintage, DÙNG_CHO_MÙA, Mùa hè)
# (Váy maxi vintage, CÓ_GIÁ, 344)
# (Váy maxi vintage, CÓ_MÔ_TẢ, Váy maxi phong cách vintage từ thương hiệu Mango, mang đến sự nữ tính và dịu dàng. Sử dụng chất liệu voan nhẹ thoáng mát, phù hợp với mùa hè.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Bộ thể thao Adidas Performance: Bộ thể thao
# Thun co giãn 4 chiều: Chất liệu
# Xám, Đen: Màu sắc
# Adidas: Thương hiệu
# Athleisure: Phong cách
# Thể thao: Loại sự kiện
# Bộ đồ thể thao Adidas Performance, thiết kế dành riêng cho những người yêu thích vận động.: Mô tả
# 853: Giá
#
# Relationships:
# (Bộ thể thao Adidas Performance, LÀM_TỪ_CHẤT_LIỆU, Thun co giãn 4 chiều)
# (Bộ thể thao Adidas Performance, CÓ_MÀU_SẮC, Xám, Đen)
# (Bộ thể thao Adidas Performance, THUỘC_THƯƠNG_HIỆU, Adidas)
# (Bộ thể thao Adidas Performance, MANG_PHONG_CÁCH, Athleisure)
# (Bộ thể thao Adidas Performance, PHÙ_HỢP_VỚI, Thể thao)
# (Bộ thể thao Adidas Performance, CÓ_GIÁ, 853)
# (Bộ thể thao Adidas Performance, CÓ_MÔ_TẢ, Bộ đồ thể thao Adidas Performance, thiết kế dành riêng cho những người yêu thích vận động.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Áo thun unisex: Sản phẩm
# Cotton: Chất liệu
# Xanh dương: Màu sắc
# Nike: Thương hiệu
# Casual: Phong cách
# Dạo phố: Sự kiện
# Áo thun unisex của Nike, chất liệu cotton thoáng mát, dễ phối đồ. Màu xanh dương nổi bật, phù hợp cho phong cách casual.: Mô tả
# 340: Giá
#
# Relationships:
# (Áo thun unisex, LÀM_TỪ_CHẤT_LIỆU, Cotton)
# (Áo thun unisex, CÓ_MÀU_SẮC, Xanh dương)
# (Áo thun unisex, THUỘC_THƯƠNG_HIỆU, Nike)
# (Áo thun unisex, MANG_PHONG_CÁCH, Casual)
# (Áo thun unisex, PHÙ_HỢP_VỚI, Dạo phố)
# (Áo thun unisex, CÓ_MÔ_TẢ, Áo thun unisex của Nike, chất liệu cotton thoáng mát, dễ phối đồ. Màu xanh dương nổi bật, phù hợp cho phong cách casual.)
# (Áo thun unisex, CÓ_GIÁ, 340)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Chân váy bút chì: Sản phẩm
# Len pha: Chất liệu
# Xám: Màu sắc
# Gucci: Thương hiệu
# Thanh lịch: Phong cách
# Công sở: Loại sự kiện
# Chân váy bút chì Gucci giúp tôn dáng với chất liệu len pha giữ ấm, thích hợp mặc trong môi trường công sở sang trọng.: Mô tả
# 964: Giá
#
# Relationships:
# (Chân váy bút chì, LÀM_TỪ_CHẤT_LIỆU, Len pha)
# (Chân váy bút chì, CÓ_MÀU_SẮC, Xám)
# (Chân váy bút chì, THUỘC_THƯƠNG_HIỆU, Gucci)
# (Chân váy bút chì, MANG_PHONG_CÁCH, Thanh lịch)
# (Chân váy bút chì, PHÙ_HỢP_VỚI, Công sở)
# (Chân váy bút chì, CÓ_GIÁ, 964)
# (Chân váy bút chì, CÓ_MÔ_TẢ, Chân váy bút chì Gucci giúp tôn dáng với chất liệu len pha giữ ấm, thích hợp mặc trong môi trường công sở sang trọng.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Giày sneaker cổ thấp: Sản phẩm
# Da tổng hợp: Chất liệu
# Trắng: Màu sắc
# Converse: Thương hiệu
# Streetwear: Phong cách
# Dạo phố: Sự kiện
# Mẫu giày sneaker cổ thấp Converse, chất liệu da tổng hợp bền bỉ, màu trắng tinh tế, dễ phối với nhiều phong cách.: Mô tả
# 850: Giá
#
# Relationships:
# (Giày sneaker cổ thấp, LÀM_TỪ_CHẤT_LIỆU, Da tổng hợp)
# (Giày sneaker cổ thấp, CÓ_MÀU_SẮC, Trắng)
# (Giày sneaker cổ thấp, THUỘC_THƯƠNG_HIỆU, Converse)
# (Giày sneaker cổ thấp, MANG_PHONG_CÁCH, Streetwear)
# (Giày sneaker cổ thấp, PHÙ_HỢP_VỚI, Dạo phố)
# (Giày sneaker cổ thấp, CÓ_MÔ_TẢ, Mẫu giày sneaker cổ thấp Converse, chất liệu da tổng hợp bền bỉ, màu trắng tinh tế, dễ phối với nhiều phong cách.)
# (Giày sneaker cổ thấp, CÓ_GIÁ, 850)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Áo hoodie nỉ: Sản phẩm
# Nỉ bông: Chất liệu
# Đỏ: Màu sắc
# Supreme: Thương hiệu
# Streetwear: Phong cách
# Dạo phố: Sự kiện
# Áo hoodie Supreme với chất nỉ bông dày dặn, màu đỏ nổi bật, giúp giữ ấm và phù hợp phong cách streetwear.: Mô tả
# 102: Giá
#
# Relationships:
# (Áo hoodie nỉ, LÀM_TỪ_CHẤT_LIỆU, Nỉ bông)
# (Áo hoodie nỉ, CÓ_MÀU_SẮC, Đỏ)
# (Áo hoodie nỉ, THUỘC_THƯƠNG_HIỆU, Supreme)
# (Áo hoodie nỉ, MANG_PHONG_CÁCH, Streetwear)
# (Áo hoodie nỉ, PHÙ_HỢP_VỚI, Dạo phố)
# (Áo hoodie nỉ, CÓ_MÔ_TẢ, Áo hoodie Supreme với chất nỉ bông dày dặn, màu đỏ nổi bật, giúp giữ ấm và phù hợp phong cách streetwear.)
# (Áo hoodie nỉ, CÓ_GIÁ, 102)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Quần short thể thao: Sản phẩm
# Polyester: Chất liệu
# Đen: Màu sắc
# Puma: Thương hiệu
# Thể thao: Phong cách
# Tập gym: Sự kiện
# Quần short thể thao Puma với chất liệu polyester thoáng khí, co giãn tốt, lý tưởng cho các hoạt động thể thao.: Mô tả
# 2350: Giá
#
# Relationships:
# (Quần short thể thao, LÀM_TỪ_CHẤT_LIỆU, Polyester)
# (Quần short thể thao, CÓ_MÀU_SẮC, Đen)
# (Quần short thể thao, THUỘC_THƯƠNG_HIỆU, Puma)
# (Quần short thể thao, MANG_PHONG_CÁCH, Thể thao)
# (Quần short thể thao, PHÙ_HỢP_VỚI, Tập gym)
# (Quần short thể thao, CÓ_GIÁ, 2350)
# (Quần short thể thao, CÓ_MÔ_TẢ, Quần short thể thao Puma với chất liệu polyester thoáng khí, co giãn tốt, lý tưởng cho các hoạt động thể thao.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Đầm bodycon: Trang phục
# Lụa pha Spandex: Chất liệu
# Đỏ rượu: Màu sắc
# Dior: Thương hiệu
# Sang trọng: Phong cách
# Dạ tiệc: Sự kiện
# Chiếc đầm bodycon Dior ôm sát, tôn dáng, chất liệu lụa pha spandex cao cấp, thích hợp cho các buổi dạ tiệc.: Mô tả
# 262: Giá
#
# Relationships:
# (Đầm bodycon, LÀM_TỪ_CHẤT_LIỆU, Lụa pha Spandex)
# (Đầm bodycon, CÓ_MÀU_SẮC, Đỏ rượu)
# (Đầm bodycon, THUỘC_THƯƠNG_HIỆU, Dior)
# (Đầm bodycon, MANG_PHONG_CÁCH, Sang trọng)
# (Đầm bodycon, PHÙ_HỢP_VỚI, Dạ tiệc)
# (Đầm bodycon, CÓ_GIÁ, 262)
# (Đầm bodycon, CÓ_MÔ_TẢ, Chiếc đầm bodycon Dior ôm sát, tôn dáng, chất liệu lụa pha spandex cao cấp, thích hợp cho các buổi dạ tiệc.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Áo blazer nữ: Sản phẩm
# Len pha: Chất liệu
# Be: Màu sắc
# Chanel: Thương hiệu
# Thanh lịch: Phong cách
# Công sở: Sự kiện
# Áo blazer Chanel màu be trang nhã, chất liệu len pha, mang lại phong cách thanh lịch và chuyên nghiệp.: Mô tả
# 560: Giá
#
# Relationships:
# (Áo blazer nữ, LÀM_TỪ_CHẤT_LIỆU, Len pha)
# (Áo blazer nữ, CÓ_MÀU_SẮC, Be)
# (Áo blazer nữ, THUỘC_THƯƠNG_HIỆU, Chanel)
# (Áo blazer nữ, MANG_PHONG_CÁCH, Thanh lịch)
# (Áo blazer nữ, PHÙ_HỢP_VỚI, Công sở)
# (Áo blazer nữ, CÓ_MÔ_TẢ, Áo blazer Chanel màu be trang nhã, chất liệu len pha, mang lại phong cách thanh lịch và chuyên nghiệp.)
# (Áo blazer nữ, CÓ_GIÁ, 560)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Túi xách da: Sản phẩm
# Da thật: Chất liệu
# Nâu: Màu sắc
# Louis Vuitton: Thương hiệu
# Sang trọng: Phong cách
# Dạo phố: Sự kiện
# Công sở: Sự kiện
# Túi xách Louis Vuitton bằng da thật, màu nâu cổ điển, là điểm nhấn hoàn hảo cho phong cách công sở hoặc dạo phố.: Mô tả
# 830: Giá
#
# Relationships:
# (Túi xách da, LÀM_TỪ_CHẤT_LIỆU, Da thật)
# (Túi xách da, CÓ_MÀU_SẮC, Nâu)
# (Túi xách da, THUỘC_THƯƠNG_HIỆU, Louis Vuitton)
# (Túi xách da, MANG_PHONG_CÁCH, Sang trọng)
# (Túi xách da, PHÙ_HỢP_VỚI, Dạo phố)
# (Túi xách da, PHÙ_HỢP_VỚI, Công sở)
# (Túi xách da, CÓ_MÔ_TẢ, Túi xách Louis Vuitton bằng da thật, màu nâu cổ điển, là điểm nhấn hoàn hảo cho phong cách công sở hoặc dạo phố.)
# (Túi xách da, CÓ_GIÁ, 830)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Mũ lưỡi trai: Sản phẩm
# Cotton: Vật liệu
# Xanh lá: Màu sắc
# New Era: Thương hiệu
# Casual: Phong cách
# Dạo phố: Sự kiện
# Mũ lưỡi trai New Era màu xanh lá, phong cách năng động, phù hợp để phối đồ casual khi dạo phố.: Mô tả
# 520: Giá
#
# Relationships:
# (Mũ lưỡi trai, LÀM_TỪ_CHẤT_LIỆU, Cotton)
# (Mũ lưỡi trai, CÓ_MÀU_SẮC, Xanh lá)
# (Mũ lưỡi trai, THUỘC_THƯƠNG_HIỆU, New Era)
# (Mũ lưỡi trai, MANG_PHONG_CÁCH, Casual)
# (Mũ lưỡi trai, PHÙ_HỢP_VỚI, Dạo phố)
# (Mũ lưỡi trai, CÓ_GIÁ, 520)
# (Mũ lưỡi trai, CÓ_MÔ_TẢ, Mũ lưỡi trai New Era màu xanh lá, phong cách năng động, phù hợp để phối đồ casual khi dạo phố.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Găng tay da: Sản phẩm
# Da thật: Chất liệu
# Đen: Màu sắc
# Prada: Thương hiệu
# Thanh lịch: Phong cách
# Mùa đông: Mùa
# 600: Giá
#
# Relationships:
# (Găng tay da, LÀM_TỪ_CHẤT_LIỆU, Da thật)
# (Găng tay da, CÓ_MÀU_SẮC, Đen)
# (Găng tay da, THUỘC_THƯƠNG_HIỆU, Prada)
# (Găng tay da, MANG_PHONG_CÁCH, Thanh lịch)
# (Găng tay da, DÙNG_CHO_MÙA, Mùa đông)
# (Găng tay da, CÓ_GIÁ, 600)
# (Găng tay da, CÓ_MÔ_TẢ, Găng tay da Prada giữ ấm tốt, màu đen sang trọng, lý tưởng để dùng trong mùa đông lạnh giá.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Áo polo nam: Sản phẩm
# Cotton co giãn: Chất liệu
# Xanh navy: Màu sắc
# Lacoste: Thương hiệu
# Casual: Phong cách
# Dạo phố: Sự kiện
# Áo polo Lacoste thiết kế đơn giản, chất liệu cotton co giãn giúp thoải mái khi mặc.: Mô tả
# 750: Giá
#
# Relationships:
# (Áo polo nam, LÀM_TỪ_CHẤT_LIỆU, Cotton co giãn)
# (Áo polo nam, CÓ_MÀU_SẮC, Xanh navy)
# (Áo polo nam, THUỘC_THƯƠNG_HIỆU, Lacoste)
# (Áo polo nam, MANG_PHONG_CÁCH, Casual)
# (Áo polo nam, PHÙ_HỢP_VỚI, Dạo phố)
# (Áo polo nam, CÓ_MÔ_TẢ, Áo polo Lacoste thiết kế đơn giản, chất liệu cotton co giãn giúp thoải mái khi mặc.)
# (Áo polo nam, CÓ_GIÁ, 750)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Váy suông midi: Loại váy
# Linen: Chất liệu
# Trắng kem: Màu sắc
# Zara: Thương hiệu
# Vintage: Phong cách
# Dạo phố: Sự kiện
# Váy suông midi Zara với chất linen nhẹ nhàng, tạo sự thoải mái và thanh lịch.: Mô tả
# 450: Giá
#
# Relationships:
# (Váy suông midi, LÀM_TỪ_CHẤT_LIỆU, Linen)
# (Váy suông midi, CÓ_MÀU_SẮC, Trắng kem)
# (Váy suông midi, THUỘC_THƯƠNG_HIỆU, Zara)
# (Váy suông midi, MANG_PHONG_CÁCH, Vintage)
# (Váy suông midi, PHÙ_HỢP_VỚI, Dạo phố)
# (Váy suông midi, CÓ_GIÁ, 450)
# (Váy suông midi, CÓ_MÔ_TẢ, Váy suông midi Zara với chất linen nhẹ nhàng, tạo sự thoải mái và thanh lịch.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Quần tây nam: Sản phẩm
# Vải wool pha: Chất liệu
# Xám đậm: Màu sắc
# Hugo Boss: Thương hiệu
# Sang trọng: Phong cách
# Công sở: Sự kiện
# Quần tây Hugo Boss chất liệu cao cấp, giúp đứng form đẹp và phù hợp môi trường công sở.: Mô tả
# 990: Giá
#
# Relationships:
# (Quần tây nam, LÀM_TỪ_CHẤT_LIỆU, Vải wool pha)
# (Quần tây nam, CÓ_MÀU_SẮC, Xám đậm)
# (Quần tây nam, THUỘC_THƯƠNG_HIỆU, Hugo Boss)
# (Quần tây nam, MANG_PHONG_CÁCH, Sang trọng)
# (Quần tây nam, PHÙ_HỢP_VỚI, Công sở)
# (Quần tây nam, CÓ_GIÁ, 990)
# (Quần tây nam, CÓ_MÔ_TẢ, Quần tây Hugo Boss chất liệu cao cấp, giúp đứng form đẹp và phù hợp môi trường công sở.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Giày oxford nam: Sản phẩm
# Da thật: Chất liệu
# Nâu: Màu sắc
# Clarks: Thương hiệu
# Thanh lịch: Phong cách
# Công sở: Sự kiện
# Giày Oxford Clarks da thật bền bỉ, thiết kế cổ điển phù hợp cho môi trường công sở.: Mô tả
# 1500: Giá
#
# Relationships:
# (Giày oxford nam, LÀM_TỪ_CHẤT_LIỆU, Da thật)
# (Giày oxford nam, CÓ_MÀU_SẮC, Nâu)
# (Giày oxford nam, THUỘC_THƯƠNG_HIỆU, Clarks)
# (Giày oxford nam, MANG_PHONG_CÁCH, Thanh lịch)
# (Giày oxford nam, PHÙ_HỢP_VỚI, Công sở)
# (Giày oxford nam, CÓ_MÔ_TẢ, Giày Oxford Clarks da thật bền bỉ, thiết kế cổ điển phù hợp cho môi trường công sở.)
# (Giày oxford nam, CÓ_GIÁ, 1500)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Dép lê thời trang: Sản phẩm
# Cao su tổng hợp: Chất liệu
# Đen: Màu sắc
# Birkenstock: Thương hiệu
# Minimalist: Phong cách
# Dạo phố: Sự kiện
# Dép lê Birkenstock mang lại sự thoải mái, phù hợp với phong cách tối giản.: Mô tả
# 700: Giá
#
# Relationships:
# (Dép lê thời trang, LÀM_TỪ_CHẤT_LIỆU, Cao su tổng hợp)
# (Dép lê thời trang, CÓ_MÀU_SẮC, Đen)
# (Dép lê thời trang, THUỘC_THƯƠNG_HIỆU, Birkenstock)
# (Dép lê thời trang, MANG_PHONG_CÁCH, Minimalist)
# (Dép lê thời trang, PHÙ_HỢP_VỚI, Dạo phố)
# (Dép lê thời trang, CÓ_MÔ_TẢ, Dép lê Birkenstock mang lại sự thoải mái, phù hợp với phong cách tối giản.)
# (Dép lê thời trang, CÓ_GIÁ, 700)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Balo vải canvas: Sản phẩm
# Canvas: Chất liệu
# Be: Màu sắc
# Fjällräven: Thương hiệu
# Casual: Phong cách
# Du lịch: Sự kiện
# Balo Fjällräven chất liệu canvas bền bỉ, phù hợp cho những chuyến đi xa hoặc sử dụng hằng ngày: Mô tả
# 1200: Giá
#
# Relationships:
# (Balo vải canvas, LÀM_TỪ_CHẤT_LIỆU, Canvas)
# (Balo vải canvas, CÓ_MÀU_SẮC, Be)
# (Balo vải canvas, THUỘC_THƯƠNG_HIỆU, Fjällräven)
# (Balo vải canvas, MANG_PHONG_CÁCH, Casual)
# (Balo vải canvas, PHÙ_HỢP_VỚI, Du lịch)
# (Balo vải canvas, CÓ_MÔ_TẢ, Balo Fjällräven chất liệu canvas bền bỉ, phù hợp cho những chuyến đi xa hoặc sử dụng hằng ngày)
# (Balo vải canvas, CÓ_GIÁ, 1200)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Áo cardigan len: Sản phẩm
# Len Merino: Chất liệu
# Xanh rêu: Màu sắc
# Uniqlo: Thương hiệu
# Minimalist: Phong cách
# Mùa thu: Mùa
# 680: Giá
#
# Relationships:
# (Áo cardigan len, LÀM_TỪ_CHẤT_LIỆU, Len Merino)
# (Áo cardigan len, CÓ_MÀU_SẮC, Xanh rêu)
# (Áo cardigan len, THUỘC_THƯƠNG_HIỆU, Uniqlo)
# (Áo cardigan len, MANG_PHONG_CÁCH, Minimalist)
# (Áo cardigan len, DÙNG_CHO_MÙA, Mùa thu)
# (Áo cardigan len, CÓ_GIÁ, 680)
# (Áo cardigan len, CÓ_MÔ_TẢ, Áo cardigan Uniqlo chất len Merino mềm mại, giữ ấm tốt trong tiết trời thu se lạnh.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Quần jogger thể thao: Quần
# Polyester co giãn: Chất liệu
# Xám nhạt: Màu sắc
# Nike: Thương hiệu
# Athleisure: Phong cách
# Tập gym: Sự kiện
# Quần jogger Nike phù hợp cho tập luyện và cả mặc hàng ngày với thiết kế thoải mái.: Mô tả
# 1050: Giá
#
# Relationships:
# (Quần jogger thể thao, LÀM_TỪ_CHẤT_LIỆU, Polyester co giãn)
# (Quần jogger thể thao, CÓ_MÀU_SẮC, Xám nhạt)
# (Quần jogger thể thao, THUỘC_THƯƠNG_HIỆU, Nike)
# (Quần jogger thể thao, MANG_PHONG_CÁCH, Athleisure)
# (Quần jogger thể thao, PHÙ_HỢP_VỚI, Tập gym)
# (Quần jogger thể thao, CÓ_MÔ_TẢ, Quần jogger Nike phù hợp cho tập luyện và cả mặc hàng ngày với thiết kế thoải mái.)
# (Quần jogger thể thao, CÓ_GIÁ, 1050)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Đầm xòe ren: Trang phục
# Ren cao cấp: Chất liệu
# Đỏ: Màu sắc
# Valentino: Thương hiệu
# Sang trọng: Phong cách
# Dạ tiệc: Sự kiện
# Thiết kế nữ tính, giúp nàng nổi bật trong mọi buổi tiệc: Mô tả
# 3200: Giá
#
# Relationships:
# (Đầm xòe ren, LÀM_TỪ_CHẤT_LIỆU, Ren cao cấp)
# (Đầm xòe ren, CÓ_MÀU_SẮC, Đỏ)
# (Đầm xòe ren, THUỘC_THƯƠNG_HIỆU, Valentino)
# (Đầm xòe ren, MANG_PHONG_CÁCH, Sang trọng)
# (Đầm xòe ren, PHÙ_HỢP_VỚI, Dạ tiệc)
# (Đầm xòe ren, CÓ_GIÁ, 3200)
# (Đầm xòe ren, CÓ_MÔ_TẢ, Thiết kế nữ tính, giúp nàng nổi bật trong mọi buổi tiệc)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Kính mát thời trang: Sản phẩm
# Nhựa acetate: Chất liệu
# Đen: Màu sắc
# Ray-Ban: Thương hiệu
# Streetwear: Phong cách
# Dạo phố: Sự kiện
# Kính mát Ray-Ban phong cách thời trang, bảo vệ mắt và tạo điểm nhấn cá tính.: Mô tả
# 950: Giá
#
# Relationships:
# (Kính mát thời trang, LÀM_TỪ_CHẤT_LIỆU, Nhựa acetate)
# (Kính mát thời trang, CÓ_MÀU_SẮC, Đen)
# (Kính mát thời trang, THUỘC_THƯƠNG_HIỆU, Ray-Ban)
# (Kính mát thời trang, MANG_PHONG_CÁCH, Streetwear)
# (Kính mát thời trang, PHÙ_HỢP_VỚI, Dạo phố)
# (Kính mát thời trang, CÓ_MÔ_TẢ, Kính mát Ray-Ban phong cách thời trang, bảo vệ mắt và tạo điểm nhấn cá tính.)
# (Kính mát thời trang, CÓ_GIÁ, 950)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Áo len cổ lọ: Sản phẩm
# Len cashmere: Chất liệu
# Nâu: Màu sắc
# Massimo Dutti: Thương hiệu
# Thanh lịch: Phong cách
# Mùa đông: Mùa
# 860: Giá
#
# Relationships:
# (Áo len cổ lọ, LÀM_TỪ_CHẤT_LIỆU, Len cashmere)
# (Áo len cổ lọ, CÓ_MÀU_SẮC, Nâu)
# (Áo len cổ lọ, THUỘC_THƯƠNG_HIỆU, Massimo Dutti)
# (Áo len cổ lọ, MANG_PHONG_CÁCH, Thanh lịch)
# (Áo len cổ lọ, DÙNG_CHO_MÙA, Mùa đông)
# (Áo len cổ lọ, CÓ_GIÁ, 860)
# (Áo len cổ lọ, CÓ_MÔ_TẢ, Áo len cổ lọ Massimo Dutti mang đến vẻ thanh lịch và giữ ấm tốt cho mùa đông lạnh.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Túi đeo chéo nam: Sản phẩm
# Da PU: Chất liệu
# Đen: Màu sắc
# Coach: Thương hiệu
# Casual: Phong cách
# Dạo phố: Sự kiện
# Túi đeo chéo Coach nhỏ gọn, tiện lợi để đựng các vật dụng cá nhân khi ra ngoài.: Mô tả
# 1100: Giá
#
# Relationships:
# (Túi đeo chéo nam, LÀM_TỪ_CHẤT_LIỆU, Da PU)
# (Túi đeo chéo nam, CÓ_MÀU_SẮC, Đen)
# (Túi đeo chéo nam, THUỘC_THƯƠNG_HIỆU, Coach)
# (Túi đeo chéo nam, MANG_PHONG_CÁCH, Casual)
# (Túi đeo chéo nam, PHÙ_HỢP_VỚI, Dạo phố)
# (Túi đeo chéo nam, CÓ_MÔ_TẢ, Túi đeo chéo Coach nhỏ gọn, tiện lợi để đựng các vật dụng cá nhân khi ra ngoài.)
# (Túi đeo chéo nam, CÓ_GIÁ, 1100)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Áo sát nách thể thao: Sản phẩm
# Vải thể thao co giãn: Chất liệu
# Trắng: Màu sắc
# Under Armour: Thương hiệu
# Thể thao: Phong cách
# Tập gym: Sự kiện
# Áo sát nách Under Armour giúp thấm hút mồ hôi tốt, lý tưởng cho những buổi tập luyện.: Mô tả
# 540: Giá
#
# Relationships:
# (Áo sát nách thể thao, LÀM_TỪ_CHẤT_LIỆU, Vải thể thao co giãn)
# (Áo sát nách thể thao, CÓ_MÀU_SẮC, Trắng)
# (Áo sát nách thể thao, THUỘC_THƯƠNG_HIỆU, Under Armour)
# (Áo sát nách thể thao, MANG_PHONG_CÁCH, Thể thao)
# (Áo sát nách thể thao, PHÙ_HỢP_VỚI, Tập gym)
# (Áo sát nách thể thao, CÓ_GIÁ, 540)
# (Áo sát nách thể thao, CÓ_MÔ_TẢ, Áo sát nách Under Armour giúp thấm hút mồ hôi tốt, lý tưởng cho những buổi tập luyện.)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Giày cao gót nữ: Sản phẩm
# Da tổng hợp: Vật liệu
# Nude: Màu sắc
# Jimmy Choo: Thương hiệu
# Sang trọng: Phong cách
# Công sở: Sự kiện
# Giày cao gót Jimmy Choo với thiết kế sang trọng, phù hợp cho công sở và các sự kiện lớn.: Mô tả
# 2800: Giá
#
# Relationships:
# (Giày cao gót nữ, LÀM_TỪ_CHẤT_LIỆU, Da tổng hợp)
# (Giày cao gót nữ, CÓ_MÀU_SẮC, Nude)
# (Giày cao gót nữ, THUỘC_THƯƠNG_HIỆU, Jimmy Choo)
# (Giày cao gót nữ, MANG_PHONG_CÁCH, Sang trọng)
# (Giày cao gót nữ, PHÙ_HỢP_VỚI, Công sở)
# (Giày cao gót nữ, CÓ_MÔ_TẢ, Giày cao gót Jimmy Choo với thiết kế sang trọng, phù hợp cho công sở và các sự kiện lớn.)
# (Giày cao gót nữ, CÓ_GIÁ, 2800)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Entities:
# Quần legging yoga: Sản phẩm
# Spandex: Chất liệu
# Tím: Màu sắc
# Lululemon: Thương hiệu
# Athleisure: Phong cách
# Yoga: Sự kiện
# Quần legging Lululemon có độ co giãn cao, giúp thoải mái vận động khi tập yoga: Mô tả
# 970: Giá
#
# Relationships:
# (Quần legging yoga, LÀM_TỪ_CHẤT_LIỆU, Spandex)
# (Quần legging yoga, CÓ_MÀU_SẮC, Tím)
# (Quần legging yoga, THUỘC_THƯƠNG_HIỆU, Lululemon)
# (Quần legging yoga, MANG_PHONG_CÁCH, Athleisure)
# (Quần legging yoga, PHÙ_HỢP_VỚI, Yoga)
# (Quần legging yoga, CÓ_MÔ_TẢ, Quần legging Lululemon có độ co giãn cao, giúp thoải mái vận động khi tập yoga)
# (Quần legging yoga, CÓ_GIÁ, 970)
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.
# Relationships added to Neo4j database.

# %%
save_schema_to_json(all_entities, all_relationships, "schema.json")
# Out:
# Schema đã được lưu vào schema.json

# %%
with open("schema.json", "r", encoding="utf-8") as f:
    schema = json.load(f)

def generate_cypher_prompt(text):
    CYPHER_GENERATION_TEMPLATE = f"""Nhiệm vụ: Tạo một truy vấn Cypher để truy vấn cơ sở dữ liệu đồ thị neo4j.
        Hướng dẫn:
        - Phân tích câu hỏi và trích xuất các thành phần đồ thị liên quan một cách linh hoạt. Sử dụng thông tin này để xây dựng truy vấn Cypher.
        - Chỉ sử dụng các loại quan hệ và thuộc tính từ sơ đồ đã cung cấp. Không bao gồm bất kỳ loại quan hệ hoặc thuộc tính nào khác.
        - Sơ đồ được xây dựng dựa trên cấu trúc đồ thị với các nút và quan hệ như sau:
        {json.dumps(schema, indent=4, ensure_ascii=False)}
        - Chỉ trả về truy vấn Cypher đã được tạo trong phản hồi của bạn. Không bao gồm giải thích, chú thích hoặc bất kỳ văn bản bổ sung nào khác. TÔI NHẮC LẠI NÓ CHỈ LÀ CÂU TRUY VẤN MÀ TÔI CÓ THỂ LẤY TOÀN BỘ VĂN BẢN CỦA BẠN ĐỂ CHẠY NHƯ 1 CÂU TRUY VẤN MÀ KHÔNG CHỨA VĂN BẢN KHÔNG PHẢI TRUY VẤN KHÔNG CẦN THIẾT
        - Đảm bảo truy vấn Cypher phản hồi chính xác câu hỏi được đưa ra theo đúng sơ đồ.
        
        Ví dụ:
        # Thiết bị nào sử dụng công nghệ IPS?
        MATCH (device)-[:CÓ_CÔNG_NGHỆ]->(techNode)
            WHERE techNode.name = 'IPS'
        RETURN device.name
        
        # Dung lượng pin của Nokia 3210 4G là gì?
        MATCH (device)-[:CÓ_DUNG_LƯỢNG_PIN]->(batteryCapacity)
            WHERE device.name = 'Nokia 3210 4G'
        RETURN batteryCapacity.name
        
        # Mạng di động nào được thiết bị hỗ trợ?
        MATCH (device)-[:HỖ_TRỢ_MẠNG]->(networkType)
            WHERE device.name = 'Nokia 3210 4G'
        RETURN networkType.name
        
        
        câu cần bạn sinh truy vấn là:
        {text}
        """

    response = model.generate_content(CYPHER_GENERATION_TEMPLATE)
    return response.text

# %%
cypher_result = generate_cypher_prompt("tôi muốn mua áo blazer nữ có giá bé hơn 1000 đô")
print(cypher_result)
# Out:
# ```cypher
# MATCH (a:`Áo blazer nữ`)
# WHERE toInteger(a.price) < 1000
# RETURN a
# ```

# %%
result = graph.query("""
MATCH (a:`Áo blazer nữ`)
WHERE toInteger(a.price) < 1000
RETURN a
""")
result
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownLabelWarning} {category: UNRECOGNIZED} {title: The provided label is not in the database.} {description: One of the labels in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing label name is: Áo blazer nữ)} {position: line: 2, column: 10, offset: 10} for query: '\nMATCH (a:`Áo blazer nữ`)\nWHERE toInteger(a.price) < 1000\nRETURN a\n'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: price)} {position: line: 3, column: 19, offset: 44} for query: '\nMATCH (a:`Áo blazer nữ`)\nWHERE toInteger(a.price) < 1000\nRETURN a\n'
# []
